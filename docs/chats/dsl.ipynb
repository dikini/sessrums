// %%
// DSL Integration for Multiparty Session Types in Rust

// 1. DSL SYNTAX DEFINITION
// Example of a Mermaid-like DSL for specifying multiparty protocols

/*
protocol FileTransfer {
    participant Client
    participant Server
    participant Storage
    
    Client -> Server: Request {
        filename: String
    }
    
    choice at Server {
        Server -> Client: FileExists {
            size: u64
        }
        Server -> Storage: FetchFile {
            path: String
        }
        Storage -> Server: FileData {
            content: Bytes
        }
        Server -> Client: FileContent {
            data: Bytes
        }
    } or {
        Server -> Client: FileNotFound {
            error: String
        }
    }
    
    rec PingPong {
        Client -> Server: Ping
        Server -> Client: Pong
        continue PingPong
    }
}
*/

// 2. MACRO SYSTEM FOR DSL PARSING

// Using proc_macro to transform the DSL into Rust code
#[proc_macro]
pub fn protocol(input: TokenStream) -> TokenStream {
    // Parse the DSL input into an AST
    let protocol_ast = parse_protocol_dsl(input);
    
    // Generate the global protocol representation
    let global_protocol = generate_global_protocol(protocol_ast);
    
    // Emit the Rust code for the global protocol
    quote! {
        pub fn global_protocol() -> impl GlobalProtocol {
            #global_protocol
        }
    }.into()
}

// 3. TYPE-LEVEL REPRESENTATION

// Global protocol representation
pub enum GlobalInteraction<Next = ()> {
    // Message from one role to another
    Message {
        from: RoleMarker,
        to: RoleMarker,
        msg_type: PhantomData<MessageType>,
        continuation: Next,
    },
    // Choice point in the protocol
    Choice {
        deciding_role: RoleMarker,
        left: Box<GlobalInteraction<Next>>,
        right: Box<GlobalInteraction<Next>>,
    },
    // Recursion point
    Rec {
        body: Box<GlobalInteraction<Next>>,
    },
    // Variable reference for recursion
    Var(usize),
    // Parallel composition
    Par {
        left: Box<GlobalInteraction<Next>>,
        right: Box<GlobalInteraction<Next>>,
    },
    // End of protocol
    End,
}

// Local protocol representation (role-specific)
pub enum LocalProtocol<R: Role, Next = ()> {
    // Send a message
    Send {
        to: RoleMarker,
        msg_type: PhantomData<MessageType>,
        continuation: Next,
    },
    // Receive a message
    Receive {
        from: RoleMarker,
        msg_type: PhantomData<MessageType>,
        continuation: Next,
    },
    // Select a branch
    Select {
        left: Box<LocalProtocol<R, Next>>,
        right: Box<LocalProtocol<R, Next>>,
    },
    // Offer branches
    Offer {
        left: Box<LocalProtocol<R, Next>>,
        right: Box<LocalProtocol<R, Next>>,
    },
    // Recursion
    Rec {
        body: Box<LocalProtocol<R, Next>>,
    },
    // Variable reference
    Var(usize),
    // End
    End,
}

// 4. PROJECTION MECHANISM

// Trait for projecting global protocols to local protocols
pub trait Project<R: Role> {
    type Output;
    fn project(self) -> Self::Output;
}

impl<Next, R: Role> Project<R> for GlobalInteraction<Next>
where
    Next: Project<R>,
{
    type Output = LocalProtocol<R, Next::Output>;
    
    fn project(self) -> Self::Output {
        match self {
            GlobalInteraction::Message { from, to, msg_type, continuation } => {
                if R::is_role(&from) {
                    // This role is sending
                    LocalProtocol::Send {
                        to,
                        msg_type,
                        continuation: continuation.project(),
                    }
                } else if R::is_role(&to) {
                    // This role is receiving
                    LocalProtocol::Receive {
                        from,
                        msg_type,
                        continuation: continuation.project(),
                    }
                } else {
                    // This role is not involved in this interaction
                    continuation.project()
                }
            },
            GlobalInteraction::Choice { deciding_role, left, right } => {
                if R::is_role(&deciding_role) {
                    // This role makes the choice
                    LocalProtocol::Select {
                        left: Box::new(left.project()),
                        right: Box::new(right.project()),
                    }
                } else {
                    // This role receives the choice
                    LocalProtocol::Offer {
                        left: Box::new(left.project()),
                        right: Box::new(right.project()),
                    }
                }
            },
            GlobalInteraction::Rec { body } => {
                LocalProtocol::Rec {
                    body: Box::new(body.project()),
                }
            },
            GlobalInteraction::Var(idx) => LocalProtocol::Var(idx),
            GlobalInteraction::Par { left, right } => {
                // Project both branches - implementation depends on role participation
                // This is a simplified approach
                let left_proj = left.project();
                let right_proj = right.project();
                
                // Combine projections (simplified)
                // Real implementation would need to handle synchronization
                left_proj
            },
            GlobalInteraction::End => LocalProtocol::End,
        }
    }
}

// 5. DSL USAGE EXAMPLES

// Example: Using the DSL to define a file transfer protocol
#[protocol]
pub const FILE_TRANSFER: &str = r#"
protocol FileTransfer {
    participant Client
    participant Server
    participant Storage
    
    Client -> Server: Request {
        filename: String
    }
    
    choice at Server {
        Server -> Client: FileExists {
            size: u64
        }
        Server -> Storage: FetchFile {
            path: String
        }
        Storage -> Server: FileData {
            content: Bytes
        }
        Server -> Client: FileContent {
            data: Bytes
        }
    } or {
        Server -> Client: FileNotFound {
            error: String
        }
    }
}
"#;

// 6. CLIENT CODE IMPLEMENTATION

// Using the projected protocol to implement type-safe communication
fn client_implementation() {
    // Get the projected protocol for the client role
    let client_protocol = FILE_TRANSFER::global_protocol().project::<Client>();
    
    // Create a session using the projected protocol
    let mut session = Session::new(client_protocol, "ws://server.example.com");
    
    // Type-safe communication follows the protocol
    session.send::<Request>(Request { filename: "example.txt".to_string() });
    
    // Handle the choice from server
    match session.receive() {
        FileExists { size } => {
            println!("File exists with size: {}", size);
            // Receive file content
            let content = session.receive::<FileContent>();
            println!("Received file data: {} bytes", content.data.len());
        },
        FileNotFound { error } => {
            println!("File not found: {}", error);
        }
    }
    
    // Session is exhausted, protocol complete
}

// 7. TRANSPORT ABSTRACTION

// Generic transport trait
pub trait Transport {
    fn send<T: Serialize>(&mut self, message: T) -> Result<(), TransportError>;
    fn receive<T: DeserializeOwned>(&mut self) -> Result<T, TransportError>;
}

// Session channel that enforces protocol adherence
pub struct Session<P, T> {
    protocol: P,
    transport: T,
    _marker: PhantomData<fn() -> P>,
}

impl<P: LocalProtocol<R>, T: Transport, R: Role> Session<P, T> {
    pub fn new(protocol: P, transport: T) -> Self {
        Self {
            protocol,
            transport,
            _marker: PhantomData,
        }
    }
    
    pub fn send<Msg>(&mut self, message: Msg) -> Result<Session<P::Next, T>, SessionError>
    where
        Msg: Serialize,
        P: AsSend<Msg>,
    {
        // Static verification that this send operation is allowed by protocol
        let next_protocol = self.protocol.after_send::<Msg>()?;
        
        // Perform the send operation
        self.transport.send(message)?;
        
        // Return updated session with advanced protocol state
        Ok(Session {
            protocol: next_protocol,
            transport: self.transport,
            _marker: PhantomData,
        })
    }
    
    pub fn receive<Msg>(&mut self) -> Result<(Msg, Session<P::Next, T>), SessionError>
    where
        Msg: DeserializeOwned,
        P: AsReceive<Msg>,
    {
        // Static verification that this receive operation is allowed by protocol
        let next_protocol = self.protocol.after_receive::<Msg>()?;
        
        // Perform the receive operation
        let message = self.transport.receive::<Msg>()?;
        
        // Return message and updated session
        Ok((message, Session {
            protocol: next_protocol,
            transport: self.transport,
            _marker: PhantomData,
        }))
    }
    
    // Additional methods for select/offer, recursion, etc.
}

// 8. PRACTICAL DSL USAGE WITH COMBINATORS

// Combinators approach for protocol composition
fn ping_pong_protocol() -> impl GlobalProtocol {
    rec(|var| {
        message::<Client, Server, Ping>(
            message::<Server, Client, Pong>(
                var
            )
        )
    })
}

// Combine protocols sequentially
let complex_protocol = 
    auth_protocol()
    .then(data_transfer_protocol())
    .then(ping_pong_protocol());

// 9. SESSION TYPE ALGEBRA

// Dual protocols (server from client)
let server_protocol = client_protocol.dual();

// Parallel composition
let combined_protocol = par(file_transfer_protocol(), monitoring_protocol());

// 10. FULL DSL EXAMPLE TRANSFORMED INTO COMBINATORS

/*
DSL:
protocol FileTransfer {
    Client -> Server: Request
    choice at Server {
        Server -> Client: Success
        Server -> Client: Data
    } or {
        Server -> Client: Error
    }
}
*/

// Equivalent with combinators:
fn file_transfer_protocol() -> impl GlobalProtocol {
    message::<Client, Server, Request>(
        choice::<Server>(
            // Left branch
            message::<Server, Client, Success>(
                message::<Server, Client, Data>(
                    end()
                )
            ),
            // Right branch
            message::<Server, Client, Error>(
                end()
            )
        )
    )
}
// Out:
// Error: the `#[proc_macro]` attribute is only usable with crates of the `proc-macro` crate type
//     ╭─[command_2:1:1]
//     │
//  46 │ #[proc_macro]
//     │ ──────┬──────
//     │       ╰──────── error: the `#[proc_macro]` attribute is only usable with crates of the `proc-macro` crate type
// ────╯
// Error: cannot find attribute `protocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │   ────┬───
//      │       ╰───── error: cannot find attribute `protocol` in this scope
// ─────╯
// Error: cannot find macro `quote` in this scope
//     ╭─[command_2:1:1]
//     │
//  55 │     quote! {
//     │     ──┬──
//     │       ╰──── error: cannot find macro `quote` in this scope
// ────╯
// [E0405] Error: cannot find trait `GlobalProtocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                                 ───────┬──────
//      │                                        ╰──────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                      │
//      │                      ╰─ help: you might be missing a type parameter: `<Client>`
//      │
//  334 │         message::<Client, Server, Ping>(
//      │                   ───┬──
//      │                      ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                      │
//      │                      ╰─ help: you might be missing a type parameter: `<Server>`
//      │
//  334 │         message::<Client, Server, Ping>(
//      │                           ───┬──
//      │                              ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Ping` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                      │
//      │                      ╰─ help: you might be missing a type parameter: `<Ping>`
//      │
//  334 │         message::<Client, Server, Ping>(
//      │                                   ──┬─
//      │                                     ╰─── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                      │
//      │                      ╰─ help: you might be missing a type parameter: `<Server>`
//      │
//  335 │             message::<Server, Client, Pong>(
//      │                       ───┬──
//      │                          ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                      │
//      │                      ╰─ help: you might be missing a type parameter: `<Client>`
//      │
//  335 │             message::<Server, Client, Pong>(
//      │                               ───┬──
//      │                                  ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Pong` in this scope
//      ╭─[command_2:1:1]
//      │
//  332 │ fn ping_pong_protocol() -> impl GlobalProtocol {
//      │                      │
//      │                      ╰─ help: you might be missing a type parameter: `<Pong>`
//      │
//  335 │             message::<Server, Client, Pong>(
//      │                                       ──┬─
//      │                                         ╰─── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `Role` in this scope
//     ╭─[command_2:1:1]
//     │
//  95 │ pub enum LocalProtocol<R: Role, Next = ()> {
//     │                           ──┬─
//     │                             ╰─── not found in this scope
// ────╯
// [E0412] Error: cannot find type `RoleMarker` in this scope
//     ╭─[command_2:1:1]
//     │
//  98 │         to: RoleMarker,
//     │             ─────┬────
//     │                  ╰────── not found in this scope
// ────╯
// [E0412] Error: cannot find type `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//   99 │         msg_type: PhantomData<MessageType>,
//      │                   ─────┬─────
//      │                        ╰─────── not found in this scope
//      │
//  202 │ // Example: Using the DSL to define a file transfer protocol
//      │                                                              │
//      │                                                              ╰─ help: consider importing this struct: `use std::marker::PhantomData;
//
// `
// ─────╯
// [E0412] Error: cannot find type `MessageType` in this scope
//     ╭─[command_2:1:1]
//     │
//  95 │ pub enum LocalProtocol<R: Role, Next = ()> {
//     │                                     │
//     │                                     ╰─ help: you might be missing a type parameter: `, MessageType`
//     │
//  99 │         msg_type: PhantomData<MessageType>,
//     │                               ─────┬─────
//     │                                    ╰─────── not found in this scope
// ────╯
// [E0412] Error: cannot find type `RoleMarker` in this scope
//      ╭─[command_2:1:1]
//      │
//  104 │         from: RoleMarker,
//      │               ─────┬────
//      │                    ╰────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//  105 │         msg_type: PhantomData<MessageType>,
//      │                   ─────┬─────
//      │                        ╰─────── not found in this scope
//      │
//  202 │ // Example: Using the DSL to define a file transfer protocol
//      │                                                              │
//      │                                                              ╰─ help: consider importing this struct: `use std::marker::PhantomData;
//
// `
// ─────╯
// [E0412] Error: cannot find type `MessageType` in this scope
//      ╭─[command_2:1:1]
//      │
//   95 │ pub enum LocalProtocol<R: Role, Next = ()> {
//      │                                     │
//      │                                     ╰─ help: you might be missing a type parameter: `, MessageType`
//      │
//  105 │         msg_type: PhantomData<MessageType>,
//      │                               ─────┬─────
//      │                                    ╰─────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `RoleMarker` in this scope
//     ╭─[command_2:1:1]
//     │
//  68 │         from: RoleMarker,
//     │               ─────┬────
//     │                    ╰────── not found in this scope
// ────╯
// [E0412] Error: cannot find type `RoleMarker` in this scope
//     ╭─[command_2:1:1]
//     │
//  69 │         to: RoleMarker,
//     │             ─────┬────
//     │                  ╰────── not found in this scope
// ────╯
// [E0412] Error: cannot find type `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//   70 │         msg_type: PhantomData<MessageType>,
//      │                   ─────┬─────
//      │                        ╰─────── not found in this scope
//      │
//  202 │ // Example: Using the DSL to define a file transfer protocol
//      │                                                              │
//      │                                                              ╰─ help: consider importing this struct: `use std::marker::PhantomData;
//
// `
// ─────╯
// [E0412] Error: cannot find type `MessageType` in this scope
//     ╭─[command_2:1:1]
//     │
//  65 │ pub enum GlobalInteraction<Next = ()> {
//     │                                │
//     │                                ╰─ help: you might be missing a type parameter: `, MessageType`
//     │
//  70 │         msg_type: PhantomData<MessageType>,
//     │                               ─────┬─────
//     │                                    ╰─────── not found in this scope
// ────╯
// [E0412] Error: cannot find type `RoleMarker` in this scope
//     ╭─[command_2:1:1]
//     │
//  75 │         deciding_role: RoleMarker,
//     │                        ─────┬────
//     │                             ╰────── not found in this scope
// ────╯
// [E0405] Error: cannot find trait `Role` in this scope
//      ╭─[command_2:1:1]
//      │
//  131 │ pub trait Project<R: Role> {
//      │                      ──┬─
//      │                        ╰─── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `Role` in this scope
//      ╭─[command_2:1:1]
//      │
//  136 │ impl<Next, R: Role> Project<R> for GlobalInteraction<Next>
//      │               ──┬─
//      │                 ╰─── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `GlobalProtocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                                     ───────┬──────
//      │                                            ╰──────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Client>`
//  373 │     message::<Client, Server, Request>(
//      │               ───┬──
//      │                  ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Server>`
//  373 │     message::<Client, Server, Request>(
//      │                       ───┬──
//      │                          ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Request` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this struct: `use std::error::Request;
//
// `
//      │
//  373 │     message::<Client, Server, Request>(
//      │                               ───┬───
//      │                                  ╰───── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Server>`
//      │
//  374 │         choice::<Server>(
//      │                  ───┬──
//      │                     ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Server>`
//      │
//  376 │             message::<Server, Client, Success>(
//      │                       ───┬──
//      │                          ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Client>`
//      │
//  376 │             message::<Server, Client, Success>(
//      │                               ───┬──
//      │                                  ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Success` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Success>`
//      │
//  376 │             message::<Server, Client, Success>(
//      │                                       ───┬───
//      │                                          ╰───── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Server>`
//      │
//  377 │                 message::<Server, Client, Data>(
//      │                           ───┬──
//      │                              ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Client>`
//      │
//  377 │                 message::<Server, Client, Data>(
//      │                                   ───┬──
//      │                                      ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Data` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Data>`
//      │
//  377 │                 message::<Server, Client, Data>(
//      │                                           ──┬─
//      │                                             ╰─── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Server` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Server>`
//      │
//  382 │             message::<Server, Client, Error>(
//      │                       ───┬──
//      │                          ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │                          │
//      │                          ╰─ help: you might be missing a type parameter: `<Client>`
//      │
//  382 │             message::<Server, Client, Error>(
//      │                               ───┬──
//      │                                  ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Error` in this scope
//      ╭─[command_2:1:1]
//      │
//  382 │             message::<Server, Client, Error>(
//      │                                       ──┬──
//      │                                         ╰──── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Client` in this scope
//      ╭─[command_2:1:1]
//      │
//  238 │ fn client_implementation() {
//      │                         │
//      │                         ╰─ help: you might be missing a type parameter: `<Client>`
//      │
//  240 │     let client_protocol = FILE_TRANSFER::global_protocol().project::<Client>();
//      │                                                                      ───┬──
//      │                                                                         ╰──── not found in this scope
// ─────╯
// [E0422] Error: cannot find struct, variant or union type `Request` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this struct: `use std::error::Request;
//
// `
//      │
//  246 │     session.send::<Request>(Request { filename: "example.txt".to_string() });
//      │                             ───┬───
//      │                                ╰───── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `Request` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this struct: `use std::error::Request;
//
// `
//      │
//  246 │     session.send::<Request>(Request { filename: "example.txt".to_string() });
//      │                    ───┬───
//      │                       ╰───── not found in this scope
// ─────╯
// [E0422] Error: cannot find struct, variant or union type `FileExists` in this scope
//      ╭─[command_2:1:1]
//      │
//  250 │         FileExists { size } => {
//      │         ─────┬────
//      │              ╰────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `FileContent` in this scope
//      ╭─[command_2:1:1]
//      │
//  238 │ fn client_implementation() {
//      │                         │
//      │                         ╰─ help: you might be missing a type parameter: `<FileContent>`
//      │
//  253 │             let content = session.receive::<FileContent>();
//      │                                             ─────┬─────
//      │                                                  ╰─────── not found in this scope
// ─────╯
// [E0422] Error: cannot find struct, variant or union type `FileNotFound` in this scope
//      ╭─[command_2:1:1]
//      │
//  256 │         FileNotFound { error } => {
//      │         ──────┬─────
//      │               ╰─────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this struct: `use std::marker::PhantomData;
//
// `
//      │
//  276 │     _marker: PhantomData<fn() -> P>,
//      │              ─────┬─────
//      │                   ╰─────── not found in this scope
// ─────╯
// [E0404] Error: expected trait, found enum `LocalProtocol`
//      ╭─[command_2:1:1]
//      │
//  279 │ impl<P: LocalProtocol<R>, T: Transport, R: Role> Session<P, T> {
//      │         ────────┬───────
//      │                 ╰───────── not a trait
// ─────╯
// [E0405] Error: cannot find trait `Role` in this scope
//      ╭─[command_2:1:1]
//      │
//  279 │ impl<P: LocalProtocol<R>, T: Transport, R: Role> Session<P, T> {
//      │                                            ──┬─
//      │                                              ╰─── not found in this scope
// ─────╯
// [E0425] Error: cannot find value `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this unit struct: `use std::marker::PhantomData;
//
// `
//      │
//  284 │             _marker: PhantomData,
//      │                      ─────┬─────
//      │                           ╰─────── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `Serialize` in this scope
//      ╭─[command_2:1:1]
//      │
//  290 │         Msg: Serialize,
//      │              ────┬────
//      │                  ╰────── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `AsSend` in this scope
//      ╭─[command_2:1:1]
//      │
//  291 │         P: AsSend<Msg>,
//      │            ───┬──
//      │               ╰──── error: cannot find trait `AsSend` in this scope
//      │               │
//      │               ╰──── help: a trait with a similar name exists: `Send`
// ─────╯
// [E0412] Error: cannot find type `SessionError` in this scope
//      ╭─[command_2:1:1]
//      │
//  279 │ impl<P: LocalProtocol<R>, T: Transport, R: Role> Session<P, T> {
//      │                                                │
//      │                                                ╰─ help: you might be missing a type parameter: `, SessionError`
//      │
//  288 │     pub fn send<Msg>(&mut self, message: Msg) -> Result<Session<P::Next, T>, SessionError>
//      │                                                                              ──────┬─────
//      │                                                                                    ╰─────── not found in this scope
// ─────╯
// [E0425] Error: cannot find value `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this unit struct: `use std::marker::PhantomData;
//
// `
//      │
//  303 │             _marker: PhantomData,
//      │                      ─────┬─────
//      │                           ╰─────── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `DeserializeOwned` in this scope
//      ╭─[command_2:1:1]
//      │
//  309 │         Msg: DeserializeOwned,
//      │              ────────┬───────
//      │                      ╰───────── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `AsReceive` in this scope
//      ╭─[command_2:1:1]
//      │
//  310 │         P: AsReceive<Msg>,
//      │            ────┬────
//      │                ╰────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `SessionError` in this scope
//      ╭─[command_2:1:1]
//      │
//  279 │ impl<P: LocalProtocol<R>, T: Transport, R: Role> Session<P, T> {
//      │                                                │
//      │                                                ╰─ help: you might be missing a type parameter: `, SessionError`
//      │
//  307 │     pub fn receive<Msg>(&mut self) -> Result<(Msg, Session<P::Next, T>), SessionError>
//      │                                                                          ──────┬─────
//      │                                                                                ╰─────── not found in this scope
// ─────╯
// [E0425] Error: cannot find value `PhantomData` in this scope
//      ╭─[command_2:1:1]
//      │
//  203 │ #[protocol]
//      │ │
//      │ ╰─ help: consider importing this unit struct: `use std::marker::PhantomData;
//
// `
//      │
//  322 │             _marker: PhantomData,
//      │                      ─────┬─────
//      │                           ╰─────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `TokenStream` in this scope
//     ╭─[command_2:1:1]
//     │
//  47 │ pub fn protocol(input: TokenStream) -> TokenStream {
//     │                        ─────┬─────
//     │                             ╰─────── not found in this scope
// ────╯
// [E0412] Error: cannot find type `TokenStream` in this scope
//     ╭─[command_2:1:1]
//     │
//  47 │ pub fn protocol(input: TokenStream) -> TokenStream {
//     │                                        ─────┬─────
//     │                                             ╰─────── not found in this scope
// ────╯
// [E0405] Error: cannot find trait `Serialize` in this scope
//      ╭─[command_2:1:1]
//      │
//  268 │     fn send<T: Serialize>(&mut self, message: T) -> Result<(), TransportError>;
//      │                ────┬────
//      │                    ╰────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `TransportError` in this scope
//      ╭─[command_2:1:1]
//      │
//  267 │ pub trait Transport {
//      │                    │
//      │                    ╰─ help: you might be missing a type parameter: `<TransportError>`
//  268 │     fn send<T: Serialize>(&mut self, message: T) -> Result<(), TransportError>;
//      │                                                                ───────┬──────
//      │                                                                       ╰──────── not found in this scope
// ─────╯
// [E0405] Error: cannot find trait `DeserializeOwned` in this scope
//      ╭─[command_2:1:1]
//      │
//  269 │     fn receive<T: DeserializeOwned>(&mut self) -> Result<T, TransportError>;
//      │                   ────────┬───────
//      │                           ╰───────── not found in this scope
// ─────╯
// [E0412] Error: cannot find type `TransportError` in this scope
//      ╭─[command_2:1:1]
//      │
//  267 │ pub trait Transport {
//      │                    │
//      │                    ╰─ help: you might be missing a type parameter: `<TransportError>`
//      │
//  269 │     fn receive<T: DeserializeOwned>(&mut self) -> Result<T, TransportError>;
//      │                                                             ───────┬──────
//      │                                                                    ╰──────── not found in this scope
// ─────╯
// [E0425] Error: cannot find value `client_protocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  351 │ let server_protocol = client_protocol.dual();
//      │                       ───────┬───────
//      │                              ╰───────── not found in this scope
// ─────╯
// [E0433] Error: failed to resolve: use of undeclared type `FILE_TRANSFER`
//      ╭─[command_2:1:1]
//      │
//  204 │ ╭─▶ pub const FILE_TRANSFER: &str = r#"
//      ┆ ┆
//  233 │ ├─▶ "#;
//      │ │
//      │ ╰───────── help: `FILE_TRANSFER` is defined here, but is not a type: ``
//      │
//  240 │         let client_protocol = FILE_TRANSFER::global_protocol().project::<Client>();
//      │                               ──────┬──────
//      │                                     ╰──────── use of undeclared type `FILE_TRANSFER`
// ─────╯
// [E0425] Error: cannot find function `rec` in this scope
//      ╭─[command_2:1:1]
//      │
//  333 │     rec(|var| {
//      │     ─┬─
//      │      ╰─── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `message` in this scope
//      ╭─[command_2:1:1]
//      │
//  334 │         message::<Client, Server, Ping>(
//      │         ───┬───
//      │            ╰───── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `message` in this scope
//      ╭─[command_2:1:1]
//      │
//  335 │             message::<Server, Client, Pong>(
//      │             ───┬───
//      │                ╰───── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `message` in this scope
//      ╭─[command_2:1:1]
//      │
//  373 │     message::<Client, Server, Request>(
//      │     ───┬───
//      │        ╰───── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `choice` in this scope
//      ╭─[command_2:1:1]
//      │
//  374 │         choice::<Server>(
//      │         ───┬──
//      │            ╰──── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `message` in this scope
//      ╭─[command_2:1:1]
//      │
//  376 │             message::<Server, Client, Success>(
//      │             ───┬───
//      │                ╰───── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `message` in this scope
//      ╭─[command_2:1:1]
//      │
//  377 │                 message::<Server, Client, Data>(
//      │                 ───┬───
//      │                    ╰───── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `end` in this scope
//      ╭─[command_2:1:1]
//      │
//  378 │                     end()
//      │                     ─┬─
//      │                      ╰─── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `message` in this scope
//      ╭─[command_2:1:1]
//      │
//  382 │             message::<Server, Client, Error>(
//      │             ───┬───
//      │                ╰───── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `end` in this scope
//      ╭─[command_2:1:1]
//      │
//  383 │                 end()
//      │                 ─┬─
//      │                  ╰─── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `parse_protocol_dsl` in this scope
//     ╭─[command_2:1:1]
//     │
//  49 │     let protocol_ast = parse_protocol_dsl(input);
//     │                        ─────────┬────────
//     │                                 ╰────────── not found in this scope
// ────╯
// [E0425] Error: cannot find function `generate_global_protocol` in this scope
//     ╭─[command_2:1:1]
//     │
//  52 │     let global_protocol = generate_global_protocol(protocol_ast);
//     │                           ────────────┬───────────
//     │                                       ╰───────────── not found in this scope
// ────╯
// [E0425] Error: cannot find function `auth_protocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  344 │     auth_protocol()
//      │     ──────┬──────
//      │           ╰──────── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `data_transfer_protocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  345 │     .then(data_transfer_protocol())
//      │           ───────────┬──────────
//      │                      ╰──────────── error: cannot find function `data_transfer_protocol` in this scope
//      │                      │
//      │                      ╰──────────── help: a function with a similar name exists: `file_transfer_protocol`
//      │
//  372 │ fn file_transfer_protocol() -> impl GlobalProtocol {
//      │ ─────────────────────────┬────────────────────────
//      │                          ╰────────────────────────── similarly named function `file_transfer_protocol` defined here
// ─────╯
// [E0425] Error: cannot find function `par` in this scope
//      ╭─[command_2:1:1]
//      │
//  354 │ let combined_protocol = par(file_transfer_protocol(), monitoring_protocol());
//      │                         ─┬─
//      │                          ╰─── not found in this scope
// ─────╯
// [E0425] Error: cannot find function `monitoring_protocol` in this scope
//      ╭─[command_2:1:1]
//      │
//  354 │ let combined_protocol = par(file_transfer_protocol(), monitoring_protocol());
//      │                                                       ─────────┬─────────
//      │                                                                ╰─────────── not found in this scope
// ─────╯
